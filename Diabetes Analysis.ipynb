# %% [markdown]
# This is an exploratory analysis of diabetes data. We start with our needed imports

# %%
import pandas as pd
import numpy as np
import re

import matplotlib.pyplot as plt

from collections import Counter

# %% [markdown]
# Now we must import our data into Pandas for processing.

# %%
df = pd.read_csv('diabetes.csv', encoding='latin1')

pd.set_option('display.max_columns', None) # Avoid truncation

# %% [markdown]
# Preliminary data exploration.

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# We don't have any unnecessary columns in our dataframe, and we don't see any signs of NaN values to be imputed. However, it is unclear as to what 0 or 1 mean for the Outcome column.
